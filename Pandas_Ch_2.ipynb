# %% [markdown]
# # Filtering and Sorting

# %%
import pandas as pd

# %%
Euro = pd.read_csv('A:\PythonPandas\Euro_2012_stats_TEAM.csv')

# %%
Euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Perform Initial Analysis

# %% [markdown]
# The data set is about Euro 2012 world cup. There are 16 rows and 35 column. The strongest team we can say is spain from the dataset. .info() will show the number of dtype.

# %%
Euro.info()

# %% [markdown]
# ### 1] How many teams participated?

# %%
Euro.Team.unique()

# %%
Euro.Team.nunique()

# %% [markdown]
# ### 2] View the dataset with Team, yellow card & red card.

# %%
Euro[['Team','Yellow Cards','Red Cards']]

# %% [markdown]
# ### 3] Sort the Teams by red cards

# %%
Euro[['Team','Red Cards']].sort_values(by = 'Red Cards', ascending=False)

# %% [markdown]
# ### 4] On an average, a Team getting how many yellow cards?

# %%
round(Euro[['Team','Yellow Cards']].mean())

# %% [markdown]
# ### 5] Filter the teams who scored more than 5 goals

# %%
Euro[Euro['Goals']>5]

# %% [markdown]
# ### 6] Get the team names starting with letter 'G'.

# %%
Euro[Euro.Team.str.startswith('G')] #bcoz team is a object type and their is no function in object convert to string and apply

# %% [markdown]
# ### 7] Get the first 10  rows of first 5 column

# %%
Euro.iloc[0:10, 0:5]
# iloc = index locator [row start : end row , column start : end column]

# %% [markdown]
# ### 8] Get top 15 records of team , Shoooting accuracy, Goals.

# %%
Euro[['Team', 'Shooting Accuracy', 'Goals']].iloc[0:15,]

# %%
Euro.iloc[:15, [0,4,1]]

# %%
for index in enumerate(Euro):
    print(index)

# %%
# loc = locator we cannot pass index number for column in loc
Euro.loc[0:15, ['Team', 'Shooting Accuracy','Goals']]

# %% [markdown]
# ### 9] To find shooting accuracy of spain, denmark, croatia

# %%
Euro = Euro.set_index('Team') # we have to set up the index or executing the below line will give error of index

# %%
Euro.loc[['Croatia','Denmark','Spain'], ['Shooting Accuracy']]

# %% [markdown]
# # =============================================================

# %%
Order = pd.read_csv('A:/PythonPandas/data.tsv.txt', sep='\t')

# %%
Order

# %% [markdown]
# ### 1] Clean the item price and make it float

# %%
Order['item_price'] = Order.item_price.str.replace('$','').astype(float)
# Out:
# <ipython-input-5-e33b180337dc>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Order['item_price'] = Order.item_price.str.replace('$','').astype(float)

# %%
# deleting column
# del Order['quantity']

# %%
Order
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
Order.drop(['order_id', 'item_price'], axis=1, inplace=False) #if inplace = true it will get deleted from main file

# %% [markdown]
# ### 2] Get the Chicken Salad Bow details

# %%
Bowl = Order[Order['item_name']=='Chicken Salad Bowl']
Bowl

# %% [markdown]
# ### 3] Select the details where chicken salad bowl quantity is 2

# %%
Bowl[Bowl['quantity']== 2]

# %%
Order[(Order['item_name']== 'Chicken Salad Bowl') & (Order['quantity']==2)]

# %% [markdown]
# ### 3] Display the items from most expensive to least expensive

# %%
Order.item_name.value_counts()

# %%
Order[['item_name', 'item_price']].sort_values(by= 'item_price', ascending=False)
# Out:
#                          item_name  item_price
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3602               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75
# ...                            ...         ...
# 3936                   Canned Soda        1.09
# 2922                 Bottled Water        1.09
# 1396                   Canned Soda        1.09
# 2562                   Canned Soda        1.09
# 1457                   Canned Soda        1.09
#
# [4622 rows x 2 columns]

# %%
# to drop the duplicate 
Order_Detail = Order[['item_name', 'item_price']]

# %%
Order

# %%
Order.item_price.max()
