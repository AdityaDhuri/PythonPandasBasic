# %%
import pandas as pd

# %%
drink = pd.read_csv('A:/PythonPandas/drinks.csv')

# %%
drink
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
drink.max()
# Out:
# country                         Zimbabwe
# beer_servings                        376
# spirit_servings                      438
# wine_servings                        370
# total_litres_of_pure_alcohol        14.4
# dtype: object

# %%
drink[drink['total_litres_of_pure_alcohol']==14.4]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 15  Belarus            142              373             42
#
#     total_litres_of_pure_alcohol continent
# 15                          14.4        EU

# %%
drink.country.nunique()
# Out:
# 193

# %% [markdown]
# ### 1] Which continent drinks more  on average?

# %%
drink.groupby('continent')['wine_servings'].mean()
# Out:
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64

# %%
drink.groupby('continent')['wine_servings'].mean().sort_values(ascending=False).head(1)
# Out:
# continent
# EU    142.222222
# Name: wine_servings, dtype: float64

# %% [markdown]
# # =======================================================

# %%
user = pd.read_csv('A:/PythonPandas/u.user', sep='|')

# %%
user
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
user.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
user.age.nunique()
# Out:
# 61

# %%
user.gender.nunique()
# Out:
# 2

# %%
user.occupation.nunique()
# Out:
# 21

# %%
user.zip_code.nunique()
# Out:
# 795

# %% [raw]
# Lesser the nunique we can group the data set, <=60 is ok

# %%
 #the user_id are added for age  anlm

# %%
user.groupby('age')['age'].sum().sort_values(ascending=False).head()
# Out:
# age
# 30    1170
# 51    1020
# 44    1012
# 28    1008
# 50    1000
# Name: age, dtype: int64

# %% [markdown]
# # ===================================================

# %%
student = pd.read_csv('A:/PythonPandas/student-mat.csv')

# %%
student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student.groupby('school').mean()
# Out:
#               age      Medu      Fedu  traveltime  studytime  failures  \
# school
# GP      16.521490  2.802292  2.553009    1.386819   2.063037  0.318052
# MS      18.021739  2.347826  2.282609    1.913043   1.826087  0.456522
#
#           famrel  freetime     goout      Dalc      Walc    health  absences  \
# school
# GP      3.959885  3.223496  3.111748  1.444126  2.260745  3.575931  5.965616
# MS      3.826087  3.326087  3.086957  1.760870  2.521739  3.391304  3.760870
#
#                G1         G2         G3
# school
# GP      10.939828  10.782235  10.489971
# MS      10.673913  10.195652   9.847826

# %%
student.age.mode()
# Out:
# 0    16
# dtype: int64

# %%
student.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %%
student.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
student.age.nunique()
# Out:
# 8

# %%
student.age.unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %% [markdown]
# ### 1] Select the detail from school to gaurdian

# %%
student.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
student_1 = student.iloc[:,0:12]
student_1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
student.loc[:,'school':'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %% [markdown]
# ##  Lambda function

# %%
student.age.apply(lambda x: x*2)
# Out:
# 0      36
# 1      34
# 2      30
# 3      30
# 4      32
#        ..
# 390    40
# 391    34
# 392    42
# 393    36
# 394    38
# Name: age, Length: 395, dtype: int64

# %% [markdown]
# ###  Add 1 to Medu and 2 to Fedu by using lambda

# %%
student[['Medu','Fedu']] =student[['Medu','Fedu']].apply(lambda x:x+2)

# %%
student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     6   at_home   teacher
# 1       GP   F   17       U     GT3       T     3     3   at_home     other
# 2       GP   F   15       U     LE3       T     3     3   at_home     other
# 3       GP   F   15       U     GT3       T     6     4    health  services
# 4       GP   F   16       U     GT3       T     5     5     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     4  services  services
# 391     MS   M   17       U     LE3       T     5     3  services  services
# 392     MS   M   21       R     GT3       T     3     3     other     other
# 393     MS   M   18       R     LE3       T     5     4  services     other
# 394     MS   M   19       U     LE3       T     3     3     other   at_home
#
# ...

# %% [markdown]
# ### Use lambda  function and capitalize the Fjob and guardian data

# %%
pd.set_option('max_columns', None)

# %%
student['guardian']= student.guardian.apply(lambda x:x.capitalize())
student['Fjob']= student.Fjob.apply(lambda x:x.capitalize())
student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     6   at_home   Teacher
# 1       GP   F   17       U     GT3       T     3     3   at_home     Other
# 2       GP   F   15       U     LE3       T     3     3   at_home     Other
# 3       GP   F   15       U     GT3       T     6     4    health  Services
# 4       GP   F   16       U     GT3       T     5     5     other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     4  services  Services
# 391     MS   M   17       U     LE3       T     5     3  services  Services
# 392     MS   M   21       R     GT3       T     3     3     other     Other
# 393     MS   M   18       R     LE3       T     5     4  services     Other
# 394     MS   M   19       U     LE3       T     3     3     other   At_home
#
# ...

# %% [markdown]
# ### Create a user-defined with a name major that returns a boolean value to a new column "legal_drinker"
# ### Note: Age eligibility is >17

# %%
pd.DataFrame(student)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     6   at_home   Teacher
# 1       GP   F   17       U     GT3       T     3     3   at_home     Other
# 2       GP   F   15       U     LE3       T     3     3   at_home     Other
# 3       GP   F   15       U     GT3       T     6     4    health  Services
# 4       GP   F   16       U     GT3       T     5     5     other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     4  services  Services
# 391     MS   M   17       U     LE3       T     5     3  services  Services
# 392     MS   M   21       R     GT3       T     3     3     other     Other
# 393     MS   M   18       R     LE3       T     5     4  services     Other
# 394     MS   M   19       U     LE3       T     3     3     other   At_home
#
# ...

# %%
student.insert(0,'legal_drinker',0)
student
# Out:
#      legal_drinker school sex  age address famsize Pstatus  Medu  Fedu  \
# 0                0     GP   F   18       U     GT3       A     6     6
# 1                0     GP   F   17       U     GT3       T     3     3
# 2                0     GP   F   15       U     LE3       T     3     3
# 3                0     GP   F   15       U     GT3       T     6     4
# 4                0     GP   F   16       U     GT3       T     5     5
# ..             ...    ...  ..  ...     ...     ...     ...   ...   ...
# 390              0     MS   M   20       U     LE3       A     4     4
# 391              0     MS   M   17       U     LE3       T     5     3
# 392              0     MS   M   21       R     GT3       T     3     3
# 393              0     MS   M   18       R     LE3       T     5     4
# 394              0     MS   M   19       U     LE3       T     3     3
#
#          Mjob      Fjob  reason guardian  traveltime  studytime  failures  \
# ...

# %%
student['legal_drinker'] = student.age.apply(lambda x:x>17)

# %%
student
# Out:
#      legal_drinker school sex  age address famsize Pstatus  Medu  Fedu  \
# 0             True     GP   F   18       U     GT3       A     6     6
# 1            False     GP   F   17       U     GT3       T     3     3
# 2            False     GP   F   15       U     LE3       T     3     3
# 3            False     GP   F   15       U     GT3       T     6     4
# 4            False     GP   F   16       U     GT3       T     5     5
# ..             ...    ...  ..  ...     ...     ...     ...   ...   ...
# 390           True     MS   M   20       U     LE3       A     4     4
# 391          False     MS   M   17       U     LE3       T     5     3
# 392           True     MS   M   21       R     GT3       T     3     3
# 393           True     MS   M   18       R     LE3       T     5     4
# 394           True     MS   M   19       U     LE3       T     3     3
#
#          Mjob      Fjob  reason guardian  traveltime  studytime  failures  \
# ...
